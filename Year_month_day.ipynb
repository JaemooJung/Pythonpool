# %%
T = int(input())
for i in range(0, T):
  ymd = input()
  year = int(ymd[0:4])
  month = int(ymd[4:6])
  day = int(ymd[6:8])
  if month > 12 or month < 1:
    print(f'#{i+1}', -1) 
  elif month in [1, 3, 5, 7, 8, 10, 12] and (day >= 1 and day <= 31) :
      print(f'#{i+1}', ymd[0:4] + '/' + ymd[4:6] + '/' + ymd[6:8])
  elif month in [4,6,9,11] and (day >= 1 and day <= 30):
      print(f'#{i+1}', ymd[0:4] + '/' + ymd[4:6] + '/' + ymd[6:8])
  elif month == 2 and (day >= 1 and day <= 28) :
      print(f'#{i+1}', ymd[0:4] + '/' + ymd[4:6] + '/' + ymd[6:8])
  else:
    print(f'#{i+1}', -1)
# Out:
# 3
# 20141111
# #1 2014/11/11
# 20151313
# #2 -1
# 20149999
# #3 -1

# %%
#참고코드
days = [0, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
T = int(input())
 
for i in range(1, T + 1):
    temp = input()
    year = temp[:4]
    month = temp[4:6]
    day = temp[6:]
 
    flag = True
 
    if int(month) <= 0 or int(month) >= 13:
        flag = False
    elif int(day) > days[int(month)] or int(day) <= 0:
        flag = False
 
    if flag:
        print("#{} {}/{}/{}".format(tc, year, month, day))
    else:
        print("#{} -1".format(tc))
